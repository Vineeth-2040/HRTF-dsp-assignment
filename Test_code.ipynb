# %%
echo "# HRTF-dsp-assignment" >> README.md
git init
git add README.md
git commit -m "first commit"
git branch -M main
git remote add origin https://github.com/Vineeth-2040/HRTF-dsp-assignment.git
git push -u origin main
